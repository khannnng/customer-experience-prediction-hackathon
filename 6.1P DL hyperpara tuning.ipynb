# %% [markdown]
# ### 0/ Import

# %%
# Basic
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# preprocess, split and metric
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score,plot_confusion_matrix,precision_recall_curve,roc_curve,make_scorer, f1_score, precision_score, recall_score, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# classifier algo
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.svm import SVC

#random
np.random.seed(42)
import random
random.seed(42)

# Settings
import warnings
warnings.filterwarnings("ignore")
import time
pd.set_option('display.max_columns', None)
from joblib import dump, load

# %%
# deep learning algo
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras import backend
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# Fixing the seed for random number generators
tf.random.set_seed(42)

# dask
from dask_ml.model_selection import GridSearchCV as DaskGridSearchCV

# keras tuner
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

# %% [markdown]
# #### Deep learning function

# %%
# Database to store result
df_accuracy = pd.DataFrame(columns=['Model name', 'Model arch.', 'Train Accuracy', 'Test_Accuracy', 'Time'])

# %%
def accuracy_vs_epochs(history, from_epoc=20):
    df = pd.DataFrame(history.history).iloc[from_epoc:]
    plt.figure(figsize = (4,2))
    plt.plot(df['accuracy'])
    plt.plot(df['val_accuracy'])
    plt.xlim(left=from_epoc-2)
    plt.title('Accuracy vs Epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='lower right')
    plt.show()

# %%
# Creating metric function 
def metrics_score(actual, predicted):
    print(classification_report(actual, predicted))
    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(6,3))
    sns.heatmap(cm, annot=True,  fmt='.2f', xticklabels=['Unsatisfied', 'Satisfied'], yticklabels=['Unsatisfied', 'Satisfied'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
training_time=0
def dl_performance(name, model, threshold=0.5):
    y_hat_train = np.where(model.predict(X_train) > threshold,1,0)
    y_hat_test = np.where(model.predict(X_test) > threshold,1,0)
    
    # calculate accuracy
    accuracy_train = round(accuracy_score(y_train, y_hat_train),5)
    accuracy_test = round(accuracy_score(y_test, y_hat_test),5)
    
    # store result
    df_accuracy.loc[len(df_accuracy.index)] = [name, model, accuracy_train, accuracy_test, training_time]
    
    # print
    print(f'Model: {name}')
    print(f'Accuracy train: {accuracy_train}')
    print(f'Accuracy test: {accuracy_test}')

    metrics_score(y_test, y_hat_test)

# %%
# export submission
def export_submission(model_name, model, note_version):
    print('Exporting ',model_name,'...')
    y_hat = np.round(model.predict(df_submit))
    df_to_submit = pd.DataFrame()
    df_to_submit['ID'] = ID_col
    df_to_submit['Overall_Experience'] = y_hat
    filename = 'submission_model_' + model_name + '_fromfile_' + note_version + '.csv'
    df_to_submit.to_csv(filename, index = False)
    print('Finish ',filename)

# %%
# function to create copyable nn model from string input
def create_DL(model_name, learning_rate=0.001):
    model_input = input()
    model_parameters = model_input.split(' ')[1::2]
    num_of_layers = model_parameters[0]
    layer_parameters = model_parameters[1:]
    if model_input.split(' ')[14] == 'learning_rate:':
        learning_rate = layer_parameters[6]
        layer_parameters = layer_parameters[:6]+layer_parameters[7:]
        
    num_of_neurons = layer_parameters[0::3]
    activator = layer_parameters[1::3]
    dropout = layer_parameters[2::3]
        
    
    #print('-'*40)
    #print('MODEL COPYABLE PARAMETERS:\n')
    print(f'# MODEL {model_name}')
    print('backend.clear_session()')
    print(model_name,'= Sequential()\n')

    print('# Layer 1 (input layer)')
    print(model_name + '.add(Dense(' + num_of_neurons[0] + ',activation=\'' + activator[0] +'\',kernel_initializer=\'he_uniform\',input_dim = X_train.shape[1]))') 
    print(model_name + '.add(Dropout(' + dropout[0] + '))')

    for i in range(1,int(num_of_layers)):
        print('#Layer', i+1)
        print(model_name + '.add(Dense(' + num_of_neurons[i] + ',activation=\'' + activator[i] +'\',kernel_initializer=\'he_uniform\'))') 
        print(model_name + '.add(Dropout(' + dropout[i] + '))')

    # Output layer
    print('#Output layer')
    print(model_name + '.add(Dense(1, activation = \'sigmoid\'))')
    print(f'optimizer = tf.keras.optimizers.Adam({learning_rate})')
    print(model_name + '.compile(loss=\'binary_crossentropy\',optimizer=optimizer,metrics=[\'accuracy\'])')

    print(f'history = {model_name}.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)')
    print('accuracy_vs_epochs(history,20)')
    print(f'dl_performance(\'{model_name}\', {model_name})')

# %%
# function to create copyable nn model from string input
def create_DL_fixed_layer(model_name, layers, learning_rate=0.001):
    model_input = 'num_layers: ' + str(layers) + ' ' + input()
    model_parameters = model_input.split(' ')[1::2]
    num_of_layers = model_parameters[0]
    layer_parameters = model_parameters[1:]
    if model_input.split(' ')[14] == 'learning_rate:':
        learning_rate = layer_parameters[6]
        layer_parameters = layer_parameters[:6]+layer_parameters[7:]
        
    num_of_neurons = layer_parameters[0::3]
    activator = layer_parameters[1::3]
    dropout = layer_parameters[2::3]
        
    
    #print('-'*40)
    #print('MODEL COPYABLE PARAMETERS:\n')
    print(f'# MODEL {model_name}')
    print('backend.clear_session()')
    print(model_name,'= Sequential()\n')

    print('# Layer 1 (input layer)')
    print(model_name + '.add(Dense(' + num_of_neurons[0] + ',activation=\'' + activator[0] +'\',kernel_initializer=\'he_uniform\',input_dim = X_train.shape[1]))') 
    print(model_name + '.add(Dropout(' + dropout[0] + '))')

    for i in range(1,int(num_of_layers)):
        print('#Layer', i+1)
        print(model_name + '.add(Dense(' + num_of_neurons[i] + ',activation=\'' + activator[i] +'\',kernel_initializer=\'he_uniform\'))') 
        print(model_name + '.add(Dropout(' + dropout[i] + '))')

    # Output layer
    print('#Output layer')
    print(model_name + '.add(Dense(1, activation = \'sigmoid\'))')
    print(f'optimizer = tf.keras.optimizers.Adam({learning_rate})')
    print(model_name + '.compile(loss=\'binary_crossentropy\',optimizer=optimizer,metrics=[\'accuracy\'])')

    print(f'history = {model_name}.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)')
    print('accuracy_vs_epochs(history,20)')
    print(f'dl_performance(\'{model_name}\', {model_name})')

# %% [markdown]
# #### Data

# %%
df = pd.read_csv('2.0.2 df_imputed.csv')
df_submit = pd.read_csv("2.0.2 df_submit_imputed.csv")

# %% [markdown]
# ### 1/ Prep

# %%
unnecessary_cols = ['ID']
df.drop(columns = unnecessary_cols, inplace=True)

ID_col = df_submit['ID']
df_submit.drop(columns = unnecessary_cols, inplace=True)

# %%
#Convert rating to numeric first
standard_rating = ['Seat_Comfort',
                   'Arrival_Time_Convenient',
                   'Catering',
                   'Onboard_Wifi_Service',
                   'Onboard_Entertainment',
                   'Online_Support',
                   'Ease_of_Online_Booking',
                   'Onboard_Service',
                   'Legroom',
                   'Baggage_Handling',
                   'CheckIn_Service',
                   'Cleanliness',
                   'Online_Boarding']

for col in standard_rating:
    df[col].replace(['Excellent', 'Good', 'Acceptable', 'Needs Improvement', 'Poor', 'Extremely Poor'],
                    [5, 4, 3, 2, 1, 0], inplace = True)
    df_submit[col].replace(['Excellent', 'Good', 'Acceptable', 'Needs Improvement', 'Poor', 'Extremely Poor'],
                    [5, 4, 3, 2, 1, 0], inplace = True)
df['Platform_Location'].replace(['Very Convenient', 'Convenient', 'Manageable', 'Needs Improvement', 'Inconvenient','Very Inconvenient'], 
                                [5,4,3,2,1,0], inplace = True)
df_submit['Platform_Location'].replace(['Very Convenient', 'Convenient', 'Manageable', 'Needs Improvement', 'Inconvenient','Very Inconvenient'], 
                                [5,4,3,2,1,0], inplace = True)
df.head(5)
# Out:
#    Overall_Experience  Seat_Comfort Seat_Class  Arrival_Time_Convenient  \
# 0                   0             2  Green Car                        5
# 1                   0             1   Ordinary                        5
# 2                   1             2  Green Car                        2
# 3                   0             3   Ordinary                        2
# 4                   1             3   Ordinary                        3
#
#    Catering  Platform_Location  Onboard_Wifi_Service  Onboard_Entertainment  \
# 0         5                  5                     4                      2
# 1         1                  2                     4                      1
# 2         2                  2                     2                      4
# 3         3                  2                     3                      2
# 4         3                  3                     2                      4
#
#    Online_Support  Ease_of_Online_Booking  Onboard_Service  Legroom  \
# 0               3                       2                2        3
# 1               4                       4                5        2
# 2               5                       5                5        5
# 3               3                       3                3        3
# 4               5                       4                4        4
#
#    Baggage_Handling  CheckIn_Service  Cleanliness  Online_Boarding  Gender  \
# 0                 2                4            2                1  Female
# 1                 1                2            4                4    Male
# 2                 5                4            5                5  Female
# 3                 3                4            3                3  Female
# 4                 4                4            4                4  Female
#
#     Customer_Type   Age      Type_Travel Travel_Class  Travel_Distance  \
# 0  Loyal Customer  52.0  Business Travel     Business              272
# 1  Loyal Customer  48.0  Personal Travel          Eco             2200
# 2  Loyal Customer  43.0  Business Travel     Business             1061
# 3  Loyal Customer  44.0  Business Travel     Business              780
# 4  Loyal Customer  50.0  Business Travel     Business             1981
#
#    Departure_Delay_in_Mins  Arrival_Delay_in_Mins
# 0                      0.0                    5.0
# 1                      9.0                    0.0
# 2                     77.0                  119.0
# 3                     13.0                   18.0
# 4                      0.0                    0.0

# %%
# Creating list of dummy columns
to_get_dummies1 = ['Seat_Class','Customer_Type','Type_Travel','Gender', 'Travel_Class',]

# Creating dummy variables
df = pd.get_dummies(data = df, columns = to_get_dummies1, drop_first = True)  
df_submit = pd.get_dummies(data = df_submit, columns = to_get_dummies1, drop_first = True)

# %% [markdown]
# #### Train data

# %%
Y = df['Overall_Experience']

# %%
X = df.drop(columns = ['Overall_Experience'])

X['Age'] = df['Age']/10
X['Travel_Distance'] = np.sqrt(df['Travel_Distance'])

X = X.values.astype(float)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=14)

scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
input_features = X_train.shape[1]

# %% [markdown]
# #### Test data

# %%
df_submit['Age'] = df_submit['Age']/10
df_submit['Travel_Distance'] = np.sqrt(df_submit['Travel_Distance'])

#df_submit['DepartureDelay_in_Mins'][df_submit['DepartureDelay_in_Mins']>0] = np.log(df_submit['DepartureDelay_in_Mins'][df_submit['DepartureDelay_in_Mins']>0])
#df_submit['ArrivalDelay_in_Mins'][df_submit['ArrivalDelay_in_Mins']>0] = np.log(df_submit['ArrivalDelay_in_Mins'][df_submit['ArrivalDelay_in_Mins']>0])

df_submit = df_submit.values.astype(float)

df_submit = scaler.transform(df_submit)

# %% [markdown]
# ### 2/ Base model DL_1

# %%
backend.clear_session()
DL_1 = Sequential()
DL_1.add(Dense(128, activation='relu', input_shape=(input_features,)))
DL_1.add(Dropout(0.2))
DL_1.add(Dense(64, activation='relu'))
DL_1.add(Dropout(0.1))
DL_1.add(Dense(1, activation='sigmoid'))
DL_1.compile(loss = 'binary_crossentropy', optimizer='adam', metrics=['accuracy'])
DL_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               3072
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 11,393
# Trainable params: 11,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time.time()
history = DL_1.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=1)
training_time = round(time.time() - start,2)
# Out:
# Epoch 1/100
# 2124/2124 [==============================] - 4s 1ms/step - loss: 0.2552 - accuracy: 0.8915 - val_loss: 0.1940 - val_accuracy: 0.9143
# Epoch 2/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1906 - accuracy: 0.9192 - val_loss: 0.1621 - val_accuracy: 0.9246
# Epoch 3/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1655 - accuracy: 0.9291 - val_loss: 0.1421 - val_accuracy: 0.9355
# Epoch 4/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1486 - accuracy: 0.9355 - val_loss: 0.1341 - val_accuracy: 0.9395
# Epoch 5/100
# 2124/2124 [==============================] - 3s 2ms/step - loss: 0.1407 - accuracy: 0.9399 - val_loss: 0.1265 - val_accuracy: 0.9435
# Epoch 6/100
# 2124/2124 [==============================] - 3s 2ms/step - loss: 0.1331 - accuracy: 0.9422 - val_loss: 0.1281 - val_accuracy: 0.9452
# Epoch 7/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1284 - accuracy: 0.9448 - val_loss: 0.1190 - val_accuracy: 0.9462
# Epoch 8/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1264 - accuracy: 0.9456 - val_loss: 0.1198 - val_accuracy: 0.9466
# Epoch 9/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1233 - accuracy: 0.9467 - val_loss: 0.1145 - val_accuracy: 0.9501
# Epoch 10/100
# 2124/2124 [==============================] - 3s 2ms/step - loss: 0.1198 - accuracy: 0.9484 - val_loss: 0.1184 - val_accuracy: 0.9469
# Epoch 11/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1180 - accuracy: 0.9481 - val_loss: 0.1185 - val_accuracy: 0.9473
# Epoch 12/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1172 - accuracy: 0.9493 - val_loss: 0.1145 - val_accuracy: 0.9499
# Epoch 13/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1148 - accuracy: 0.9499 - val_loss: 0.1103 - val_accuracy: 0.9495
# Epoch 14/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1132 - accuracy: 0.9510 - val_loss: 0.1131 - val_accuracy: 0.9514
# Epoch 15/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1124 - accuracy: 0.9510 - val_loss: 0.1114 - val_accuracy: 0.9531
# Epoch 16/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1120 - accuracy: 0.9513 - val_loss: 0.1099 - val_accuracy: 0.9519
# Epoch 17/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1112 - accuracy: 0.9518 - val_loss: 0.1082 - val_accuracy: 0.9535
# Epoch 18/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1096 - accuracy: 0.9524 - val_loss: 0.1127 - val_accuracy: 0.9539
# Epoch 19/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1089 - accuracy: 0.9524 - val_loss: 0.1099 - val_accuracy: 0.9517
# Epoch 20/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1082 - accuracy: 0.9532 - val_loss: 0.1099 - val_accuracy: 0.9517
# Epoch 21/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1065 - accuracy: 0.9540 - val_loss: 0.1094 - val_accuracy: 0.9535
# Epoch 22/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1076 - accuracy: 0.9534 - val_loss: 0.1099 - val_accuracy: 0.9501
# Epoch 23/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1051 - accuracy: 0.9537 - val_loss: 0.1090 - val_accuracy: 0.9551
# Epoch 24/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1041 - accuracy: 0.9540 - val_loss: 0.1104 - val_accuracy: 0.9523
# Epoch 25/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.1051 - accuracy: 0.9548 - val_loss: 0.1095 - val_accuracy: 0.9544
# Epoch 26/100
# 2124/2124 [==============================] - 3s 2ms/step - loss: 0
100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0876 - accuracy: 0.9621 - val_loss: 0.1188 - val_accuracy: 0.9507
# Epoch 88/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0873 - accuracy: 0.9618 - val_loss: 0.1169 - val_accuracy: 0.9519
# Epoch 89/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0889 - accuracy: 0.9614 - val_loss: 0.1168 - val_accuracy: 0.9514
# Epoch 90/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0881 - accuracy: 0.9620 - val_loss: 0.1165 - val_accuracy: 0.9514
# Epoch 91/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0876 - accuracy: 0.9622 - val_loss: 0.1145 - val_accuracy: 0.9517
# Epoch 92/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0881 - accuracy: 0.9617 - val_loss: 0.1139 - val_accuracy: 0.9511
# Epoch 93/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0871 - accuracy: 0.9621 - val_loss: 0.1150 - val_accuracy: 0.9515
# Epoch 94/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0860 - accuracy: 0.9629 - val_loss: 0.1167 - val_accuracy: 0.9515
# Epoch 95/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0865 - accuracy: 0.9620 - val_loss: 0.1182 - val_accuracy: 0.9517
# Epoch 96/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0881 - accuracy: 0.9621 - val_loss: 0.1182 - val_accuracy: 0.9490
# Epoch 97/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0873 - accuracy: 0.9619 - val_loss: 0.1155 - val_accuracy: 0.9539
# Epoch 98/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0877 - accuracy: 0.9619 - val_loss: 0.1133 - val_accuracy: 0.9534
# Epoch 99/100
# 2124/2124 [==============================] - 3s 2ms/step - loss: 0.0866 - accuracy: 0.9632 - val_loss: 0.1184 - val_accuracy: 0.9497
# Epoch 100/100
# 2124/2124 [==============================] - 3s 1ms/step - loss: 0.0861 - accuracy: 0.9632 - val_loss: 0.1159 - val_accuracy: 0.9513

# %%
print(dl_performance('DL_1', DL_1))
accuracy_vs_epochs(history,20)
# Out:
# 2360/2360 [==============================] - 2s 759us/step
# 590/590 [==============================] - 0s 803us/step
# Model name                                                     DL_1
# Model arch.       <keras.engine.sequential.Sequential object at ...
# Train Accuracy                                              0.97154
# Test_Accuracy                                               0.95582
# Time                                                          308.0
# Name: 0, dtype: object

# %%
backend.clear_session()

# %% [markdown]
# ### 3/ 3 layer

# %%
backend.clear_session()

# %% [markdown]
# Adjust the tuning function in a way that starts with large neuron depending on the number of layers and decrease subsequently.

# %%
# debug
# no_of_layers = 4
# neurons_per_layer = [32,32,64,128,196,256,256,256,320,320,320,320]

# for i in range(no_of_layers):
#     print(str(i), neurons_per_layer[(no_of_layers-i):(no_of_layers-i+3)])

# %%
def build_model(h):
    model = keras.Sequential()
    # Number of layer: min - max
    no_of_layers = 3 # h.Int('num_layers', 2, 8)
    neurons_per_layer = [32,32,64,128,196,256,256,256,320,320,320,320]

    for i in range(no_of_layers):
        model.add(layers.Dense(
            units=h.Choice('units_' + str(i), neurons_per_layer[(no_of_layers-i):(no_of_layers-i+3)]),
            # Activation function for each layer
            activation= h.Choice('act_' + str(i), ['relu','sigmoid'])))
        # Tune with dropout or not
        model.add(Dropout(h.Choice('dropout_'+ str(i), [0.0, 0.1,0.2,0.5])))
    # output layer
    model.add(layers.Dense(1, activation='sigmoid'))
    # compiler
    model.compile(
        # Adjust learning rate
        optimizer=keras.optimizers.Adam(h.Choice('learning_rate', [1e-2, 1e-3])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=7,  #defaul 5-7
    executions_per_trial=3, #defaul 3-5
    project_name='Job',
    overwrite=True)
#tuner.search_space_summary()
start = time.time()
tuner.search(X_train, y_train, epochs=8, # default about 5-10
             validation_data = (X_test,y_test))
print('Tuning completed in: ', round(time.time()-start,2),'s')
tuner.results_summary()
# Out:
# Trial 7 Complete [00h 01m 42s]
# val_accuracy: 0.9450801610946655
#
# Best val_accuracy So Far: 0.951543390750885
# Total elapsed time: 00h 12m 22s
# INFO:tensorflow:Oracle triggered exit
# Tuning completed in:  741.84 s
# Results summary
# Results in .\Job
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000018DD90E03A0>
# Trial summary
# Hyperparameters:
# units_0: 128
# act_0: relu
# dropout_0: 0.2
# units_1: 64
# act_1: relu
# dropout_1: 0.0
# units_2: 64
# act_2: relu
# dropout_2: 0.1
# learning_rate: 0.001
# Score: 0.951543390750885
# Trial summary
# Hyperparameters:
# units_0: 196
# act_0: relu
# dropout_0: 0.5
# units_1: 196
# act_1: sigmoid
# dropout_1: 0.0
# units_2: 128
# act_2: relu
# dropout_2: 0.1
# learning_rate: 0.001
# Score: 0.9493007063865662
# Trial summary
# Hyperparameters:
# units_0: 196
# act_0: relu
# dropout_0: 0.5
# units_1: 128
# act_1: sigmoid
# dropout_1: 0.0
# units_2: 128
# act_2: relu
# dropout_2: 0.0
# learning_rate: 0.001
# Score: 0.9491241176923116
# Trial summary
# Hyperparameters:
# units_0: 196
# act_0: relu
# dropout_0: 0.5
# units_1: 128
# act_1: sigmoid
# dropout_1: 0.1
# units_2: 128
# act_2: sigmoid
# dropout_2: 0.1
# learning_rate: 0.001
# Score: 0.9481352170308431
# Trial summary
# Hyperparameters:
# units_0: 128
# act_0: relu
# dropout_0: 0.1
# units_1: 196
# act_1: sigmoid
# dropout_1: 0.0
# units_2: 64
# act_2: relu
# dropout_2: 0.0
# learning_rate: 0.01
# Score: 0.9450801610946655
# Trial summary
# Hyperparameters:
# units_0: 128
# act_0: relu
# dropout_0: 0.5
# units_1: 64
# act_1: sigmoid
# dropout_1: 0.1
# units_2: 128
# act_2: sigmoid
# dropout_2: 0.2
# learning_rate: 0.001
# Score: 0.9443031748135885
# Trial summary
# Hyperparameters:
# units_0: 196
# act_0: sigmoid
# dropout_0: 0.5
# units_1: 196
# act_1: relu
# dropout_1: 0.2
# units_2: 64
# act_2: relu
# dropout_2: 0.0
# learning_rate: 0.001
# Score: 0.9325775106747946

# %% [markdown]
# #### Build model with above parameter

# %% [markdown]
# ##### Model DL_tune1

# %%
create_DL_fixed_layer('DL_tune1', 3)
# Out:
#  units_0: 128 act_0: relu dropout_0: 0.2 units_1: 64 act_1: relu dropout_1: 0.0 units_2: 64 act_2: relu dropout_2: 0.1 learning_rate: 0.001
# # MODEL DL_tune1
# backend.clear_session()
# DL_tune1 = Sequential()
#
# # Layer 1 (input layer)
# DL_tune1.add(Dense(128,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
# DL_tune1.add(Dropout(0.2))
# #Layer 2
# DL_tune1.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
# DL_tune1.add(Dropout(0.0))
# #Layer 3
# DL_tune1.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
# DL_tune1.add(Dropout(0.1))
# #Output layer
# DL_tune1.add(Dense(1, activation = 'sigmoid'))
# optimizer = tf.keras.optimizers.Adam(0.001)
# DL_tune1.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
# history = DL_tune1.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
# accuracy_vs_epochs(history,20)
# dl_performance('DL_tune1', DL_tune1)

# %%
# MODEL DL_tune1
backend.clear_session()
DL_tune1 = Sequential()

# Layer 1 (input layer)
DL_tune1.add(Dense(128,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
DL_tune1.add(Dropout(0.2))
#Layer 2
DL_tune1.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
DL_tune1.add(Dropout(0.0))
#Layer 3
DL_tune1.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
DL_tune1.add(Dropout(0.1))
#Output layer
DL_tune1.add(Dense(1, activation = 'sigmoid'))
optimizer = tf.keras.optimizers.Adam(0.001)
DL_tune1.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history = DL_tune1.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
accuracy_vs_epochs(history,20)
dl_performance('DL_tune1', DL_tune1)
# Out:
# Epoch 1/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.2872 - accuracy: 0.8759 - val_loss: 0.2045 - val_accuracy: 0.9109
# Epoch 2/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.2114 - accuracy: 0.9105 - val_loss: 0.1767 - val_accuracy: 0.9192
# Epoch 3/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1882 - accuracy: 0.9199 - val_loss: 0.1606 - val_accuracy: 0.9297
# Epoch 4/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1720 - accuracy: 0.9263 - val_loss: 0.1506 - val_accuracy: 0.9329
# Epoch 5/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1606 - accuracy: 0.9313 - val_loss: 0.1474 - val_accuracy: 0.9350
# Epoch 6/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1545 - accuracy: 0.9339 - val_loss: 0.1419 - val_accuracy: 0.9372
# Epoch 7/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1475 - accuracy: 0.9365 - val_loss: 0.1369 - val_accuracy: 0.9392
# Epoch 8/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1411 - accuracy: 0.9392 - val_loss: 0.1343 - val_accuracy: 0.9401
# Epoch 9/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1378 - accuracy: 0.9403 - val_loss: 0.1287 - val_accuracy: 0.9436
# Epoch 10/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1341 - accuracy: 0.9415 - val_loss: 0.1317 - val_accuracy: 0.9387
# Epoch 11/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1309 - accuracy: 0.9423 - val_loss: 0.1304 - val_accuracy: 0.9409
# Epoch 12/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1300 - accuracy: 0.9437 - val_loss: 0.1293 - val_accuracy: 0.9436
# Epoch 13/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1274 - accuracy: 0.9446 - val_loss: 0.1261 - val_accuracy: 0.9431
# Epoch 14/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1244 - accuracy: 0.9458 - val_loss: 0.1267 - val_accuracy: 0.9444
# Epoch 15/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1233 - accuracy: 0.9463 - val_loss: 0.1231 - val_accuracy: 0.9445
# Epoch 16/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1221 - accuracy: 0.9468 - val_loss: 0.1229 - val_accuracy: 0.9441
# Epoch 17/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1191 - accuracy: 0.9475 - val_loss: 0.1228 - val_accuracy: 0.9464
# Epoch 18/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1168 - accuracy: 0.9485 - val_loss: 0.1202 - val_accuracy: 0.9456
# Epoch 19/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1160 - accuracy: 0.9490 - val_loss: 0.1205 - val_accuracy: 0.9464
# Epoch 20/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1143 - accuracy: 0.9496 - val_loss: 0.1190 - val_accuracy: 0.9458
# Epoch 21/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1148 - accuracy: 0.9493 - val_loss: 0.1200 - val_accuracy: 0.9476
# Epoch 22/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1139 - accuracy: 0.9503 - val_loss: 0.1190 - val_accuracy: 0.9470
# Epoch 23/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1124 - accuracy: 0.9507 - val_loss: 0.1195 - val_accuracy: 0.9495
# Epoch 24/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1102 - accuracy: 0.9520 - val_loss: 0.1214 - val_accuracy: 0.9480
# Epoch 25/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1105 - accuracy: 0.9510 - val_loss: 0.1183 - val_accuracy: 0.9466
# Epoch 26/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1092 - accuracy: 0.9520 - val_loss: 0.1203 - val_accuracy: 0.9477
# Epoch 27/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1080 - accuracy: 0.9523 - val_loss: 0.1202 - val_accuracy: 0.9494
# Epoch 28/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1073 - accuracy: 0.9518 - val_loss: 0.1193 - val_accuracy: 0.9485
# Epoch 29/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1062 - accuracy: 0.9527 - val_loss: 0.1182 - val_accuracy: 0.9497
# Epoch 30/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1061 - accuracy: 0.9534 - val_loss: 0.1223 - val_accuracy: 0.9466
# Epoch 31/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1044 - accuracy: 0.9536 - val_loss: 0.1215 - val_accuracy: 0.9498
# Epoch 32/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1049 - accuracy: 0.9534 - val_loss: 0.1217 - val_accuracy: 0.9473
# Epoch 33/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1045 - accuracy: 0.9532 - val_loss: 0.1175 - val_accuracy: 0.9486
# Epoch 34/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1014 - accuracy: 0.9544 - val_loss: 0.1223 - val_accuracy: 0.9481
# Epoch 35/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1024 - accuracy: 0.9553 - val_loss: 0.1219 - val_accuracy: 0.9499
# Epoch 36/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1017 - accuracy: 0.9548 - val_loss: 0.1202 - val_accuracy: 0.9502
# Epoch 37/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1016 - accuracy: 0.9545 - val_loss: 0.1233 - val_accuracy: 0.9506
# Epoch 38/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0998 - accuracy: 0.9559 - val_loss: 0.1168 - val_accuracy: 0.9506
# Epoch 39/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0996 - accuracy: 0.9559 - val_loss: 0.1169 - val_accuracy: 0.9501
# Epoch 40/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1006 - accuracy: 0.9560 - val_loss: 0.1149 - val_accuracy: 0.9510
# Epoch 41/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0981 - accuracy: 0.9562 - val_loss: 0.1182 - val_accuracy: 0.9507
# Epoch 42/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0979 - accuracy: 0.9566 - val_loss: 0.1181 - val_accuracy: 0.9485
# Epoch 43/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0965 - accuracy: 0.9576 - val_loss: 0.1168 - val_accuracy: 0.9523
# Epoch 44/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0968 - accuracy: 0.9565 - val_loss: 0.1194 - val_accuracy: 0.9480
# Epoch 45/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0963 - accuracy: 0.9572 - val_loss: 0.1187 - val_accuracy: 0.9498
# Epoch 46/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0960 - accuracy: 0.9570 - val_loss: 0.1173 - val_accuracy: 0.9499
# Epoch 47/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0964 - accuracy: 0.9574 - val_loss: 0.1162 - val_accuracy: 0.9507
# Epoch 48/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0956 - accuracy: 0.9578 - val_loss: 0.1176 - val_accuracy: 0.9509
# Epoch 49/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0956 - accuracy: 0.9573 - val_loss: 0.1199 - val_accuracy: 0.9491
# Epoch 50/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.0942 - accuracy: 0.9580 - val_loss: 0.1233 - val_accuracy: 0.9482
# 2360/2360 [==============================] - 2s 758us/step
# 590/590 [==============================] - 0s 760us/step
# Model: DL_tune1
# Accuracy train: 0.96556
# Accuracy test: 0.95264
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      8576
#            1       0.96      0.95      0.96     10300
#
#     accuracy                           0.95     18876
#    macro avg       0.95      0.95      0.95     18876
# weighted avg       0.95      0.95      0.95     18876

# %% [markdown]
# ### 4/ 4 layers

# %%
backend.clear_session()

# %%
def build_model(h):
    model = keras.Sequential()
    # Number of layer: min - max
    no_of_layers = 4 # h.Int('num_layers', 2, 8)
    neurons_per_layer = [32,32,64,128,196,256,256,256,320,320,320,320]

    for i in range(no_of_layers):
        model.add(layers.Dense(
            units=h.Choice('units_' + str(i), neurons_per_layer[(no_of_layers-i):(no_of_layers-i+3)]),
            # Activation function for each layer
            activation= h.Choice('act_' + str(i), ['relu','sigmoid'])))
        # Tune with dropout or not
        model.add(Dropout(h.Choice('dropout_'+ str(i), [0.0, 0.1,0.2,0.5])))
    # output layer
    model.add(layers.Dense(1, activation='sigmoid'))
    # compiler
    model.compile(
        # Adjust learning rate
        optimizer=keras.optimizers.Adam(h.Choice('learning_rate', [1e-2, 1e-3])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,  #defaul 5-7
    executions_per_trial=3, #defaul 3-5
    project_name='Job',
    overwrite=True)
#tuner.search_space_summary()
start = time.time()
tuner.search(X_train, y_train, epochs=8, # default about 5-10
             validation_data = (X_test,y_test))
print('Tuning completed in: ', round(time.time()-start,2),'s')
tuner.results_summary()
# Out:
# Trial 5 Complete [00h 02m 15s]
# val_accuracy: 0.9423960049947103
#
# Best val_accuracy So Far: 0.9513314962387085
# Total elapsed time: 00h 10m 57s
# INFO:tensorflow:Oracle triggered exit
# Tuning completed in:  657.45 s
# Results summary
# Results in .\Job
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000018DF2DEFBB0>
# Trial summary
# Hyperparameters:
# units_0: 196
# act_0: relu
# dropout_0: 0.2
# units_1: 128
# act_1: relu
# dropout_1: 0.1
# units_2: 64
# act_2: relu
# dropout_2: 0.5
# units_3: 64
# act_3: relu
# dropout_3: 0.1
# learning_rate: 0.001
# Score: 0.9513314962387085
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: relu
# dropout_0: 0.5
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.5
# units_2: 196
# act_2: sigmoid
# dropout_2: 0.1
# units_3: 64
# act_3: sigmoid
# dropout_3: 0.2
# learning_rate: 0.001
# Score: 0.9461926817893982
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: sigmoid
# dropout_0: 0.2
# units_1: 128
# act_1: sigmoid
# dropout_1: 0.1
# units_2: 196
# act_2: relu
# dropout_2: 0.1
# units_3: 64
# act_3: relu
# dropout_3: 0.5
# learning_rate: 0.01
# Score: 0.9423960049947103
# Trial summary
# Hyperparameters:
# units_0: 196
# act_0: relu
# dropout_0: 0.2
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.5
# units_2: 64
# act_2: sigmoid
# dropout_2: 0.2
# units_3: 64
# act_3: sigmoid
# dropout_3: 0.1
# learning_rate: 0.01
# Score: 0.9383697112401327
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: sigmoid
# dropout_0: 0.0
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.0
# units_2: 196
# act_2: relu
# dropout_2: 0.5
# units_3: 128
# act_3: relu
# dropout_3: 0.5
# learning_rate: 0.01
# Score: 0.9325775305430094

# %% [markdown]
# #### Build model with above parameter

# %%
create_DL_fixed_layer('DL_tune2', 4)
# Out:
#  units_0: 196 act_0: relu dropout_0: 0.2 units_1: 128 act_1: relu dropout_1: 0.1 units_2: 64 act_2: relu dropout_2: 0.5 units_3: 64 act_3: relu dropout_3: 0.1 learning_rate: 0.001
# # MODEL DL_tune2
# backend.clear_session()
# DL_tune2 = Sequential()
#
# # Layer 1 (input layer)
# DL_tune2.add(Dense(196,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
# DL_tune2.add(Dropout(0.2))
# #Layer 2
# DL_tune2.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
# DL_tune2.add(Dropout(0.1))
# #Layer 3
# DL_tune2.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
# DL_tune2.add(Dropout(0.5))
# #Layer 4
# DL_tune2.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
# DL_tune2.add(Dropout(0.1))
# #Output layer
# DL_tune2.add(Dense(1, activation = 'sigmoid'))
# optimizer = tf.keras.optimizers.Adam(0.001)
# DL_tune2.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
# history = DL_tune2.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
# accuracy_vs_epochs(history,20)
# dl_performance('DL_tune2', DL_tune2)

# %%
# MODEL DL_tune2
backend.clear_session()
DL_tune2 = Sequential()

# Layer 1 (input layer)
DL_tune2.add(Dense(196,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
DL_tune2.add(Dropout(0.2))
#Layer 2
DL_tune2.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
DL_tune2.add(Dropout(0.1))
#Layer 3
DL_tune2.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
DL_tune2.add(Dropout(0.5))
#Layer 4
DL_tune2.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
DL_tune2.add(Dropout(0.1))
#Output layer
DL_tune2.add(Dense(1, activation = 'sigmoid'))
optimizer = tf.keras.optimizers.Adam(0.001)
DL_tune2.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history = DL_tune2.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
accuracy_vs_epochs(history,20)
dl_performance('DL_tune2', DL_tune2)
# Out:
# Epoch 1/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.3217 - accuracy: 0.8626 - val_loss: 0.2149 - val_accuracy: 0.9068
# Epoch 2/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.2234 - accuracy: 0.9080 - val_loss: 0.1823 - val_accuracy: 0.9188
# Epoch 3/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1946 - accuracy: 0.9174 - val_loss: 0.1678 - val_accuracy: 0.9269
# Epoch 4/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1792 - accuracy: 0.9237 - val_loss: 0.1601 - val_accuracy: 0.9310
# Epoch 5/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1678 - accuracy: 0.9288 - val_loss: 0.1489 - val_accuracy: 0.9344
# Epoch 6/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1581 - accuracy: 0.9324 - val_loss: 0.1440 - val_accuracy: 0.9374
# Epoch 7/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1509 - accuracy: 0.9362 - val_loss: 0.1418 - val_accuracy: 0.9404
# Epoch 8/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1449 - accuracy: 0.9378 - val_loss: 0.1384 - val_accuracy: 0.9416
# Epoch 9/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1413 - accuracy: 0.9394 - val_loss: 0.1373 - val_accuracy: 0.9401
# Epoch 10/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1361 - accuracy: 0.9411 - val_loss: 0.1286 - val_accuracy: 0.9427
# Epoch 11/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1330 - accuracy: 0.9429 - val_loss: 0.1314 - val_accuracy: 0.9446
# Epoch 12/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1296 - accuracy: 0.9447 - val_loss: 0.1270 - val_accuracy: 0.9438
# Epoch 13/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1270 - accuracy: 0.9456 - val_loss: 0.1209 - val_accuracy: 0.9454
# Epoch 14/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1244 - accuracy: 0.9466 - val_loss: 0.1219 - val_accuracy: 0.9484
# Epoch 15/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1227 - accuracy: 0.9470 - val_loss: 0.1264 - val_accuracy: 0.9460
# Epoch 16/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1210 - accuracy: 0.9482 - val_loss: 0.1205 - val_accuracy: 0.9476
# Epoch 17/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1188 - accuracy: 0.9491 - val_loss: 0.1256 - val_accuracy: 0.9482
# Epoch 18/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1156 - accuracy: 0.9498 - val_loss: 0.1378 - val_accuracy: 0.9456
# Epoch 19/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1153 - accuracy: 0.9504 - val_loss: 0.1188 - val_accuracy: 0.9511
# Epoch 20/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1135 - accuracy: 0.9511 - val_loss: 0.1245 - val_accuracy: 0.9470
# Epoch 21/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1122 - accuracy: 0.9518 - val_loss: 0.1167 - val_accuracy: 0.9489
# Epoch 22/50
# 1062/1062 [==============================] - 3s 2ms/step - loss: 0.1117 - accuracy: 0.9513 - val_loss: 0.1157 - val_accuracy: 0.9494
# Epoch 23/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1106 - accuracy: 0.9521 - val_loss: 0.1162 - val_accuracy: 0.9525
# Epoch 24/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1079 - accuracy: 0.9530 - val_loss: 0.1154 - val_accuracy: 0.9487
# Epoch 25/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.1077 - accuracy: 0.9528 - val_loss: 0.1139 - val_accuracy: 0.9503
# Epoch 26/50
# 1062/1062 [==============================] - 2s 2ms/step - loss: 0.
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      8576
#            1       0.97      0.94      0.96     10300
#
#     accuracy                           0.95     18876
#    macro avg       0.95      0.95      0.95     18876
# weighted avg       0.95      0.95      0.95     18876

# %% [markdown]
# ### 5/ 5 layers

# %%
backend.clear_session()

# %%
def build_model(h):
    model = keras.Sequential()
    # Number of layer: min - max
    no_of_layers = 5 # h.Int('num_layers', 2, 8)
    neurons_per_layer = [32,32,64,128,196,256,256,256,320,320,320,320]

    for i in range(no_of_layers):
        model.add(layers.Dense(
            units=h.Choice('units_' + str(i), neurons_per_layer[(no_of_layers-i):(no_of_layers-i+3)]),
            # Activation function for each layer
            activation= h.Choice('act_' + str(i), ['relu','sigmoid'])))
        # Tune with dropout or not
        model.add(Dropout(h.Choice('dropout_'+ str(i), [0.0, 0.1,0.2,0.5])))
    # output layer
    model.add(layers.Dense(1, activation='sigmoid'))
    # compiler
    model.compile(
        # Adjust learning rate
        optimizer=keras.optimizers.Adam(h.Choice('learning_rate', [1e-2, 1e-3])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,  #defaul 5-7
    executions_per_trial=3, #defaul 3-5
    project_name='Job',
    overwrite=True)
#tuner.search_space_summary()
start = time.time()
tuner.search(X_train, y_train, epochs=8, # default about 5-10
             validation_data = (X_test,y_test))
print('Tuning completed in: ', round(time.time()-start,2),'s')
tuner.results_summary()
# Out:
# Trial 5 Complete [00h 02m 31s]
# val_accuracy: 0.9340432484944662
#
# Best val_accuracy So Far: 0.952090859413147
# Total elapsed time: 00h 12m 12s
# INFO:tensorflow:Oracle triggered exit
# Tuning completed in:  731.83 s
# Results summary
# Results in .\Job
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000018DDCF81670>
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: relu
# dropout_0: 0.1
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.2
# units_2: 196
# act_2: relu
# dropout_2: 0.0
# units_3: 196
# act_3: sigmoid
# dropout_3: 0.1
# units_4: 128
# act_4: sigmoid
# dropout_4: 0.1
# learning_rate: 0.001
# Score: 0.952090859413147
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: relu
# dropout_0: 0.5
# units_1: 196
# act_1: sigmoid
# dropout_1: 0.0
# units_2: 128
# act_2: sigmoid
# dropout_2: 0.0
# units_3: 196
# act_3: relu
# dropout_3: 0.1
# units_4: 128
# act_4: relu
# dropout_4: 0.0
# learning_rate: 0.001
# Score: 0.9495302637418112
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: sigmoid
# dropout_0: 0.1
# units_1: 256
# act_1: relu
# dropout_1: 0.2
# units_2: 196
# act_2: sigmoid
# dropout_2: 0.1
# units_3: 128
# act_3: relu
# dropout_3: 0.0
# units_4: 64
# act_4: relu
# dropout_4: 0.2
# learning_rate: 0.001
# Score: 0.9405417839686075
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: relu
# dropout_0: 0.2
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.5
# units_2: 196
# act_2: sigmoid
# dropout_2: 0.1
# units_3: 128
# act_3: sigmoid
# dropout_3: 0.0
# units_4: 32
# act_4: relu
# dropout_4: 0.2
# learning_rate: 0.01
# Score: 0.9340432484944662
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: sigmoid
# dropout_0: 0.2
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.0
# units_2: 128
# act_2: relu
# dropout_2: 0.5
# units_3: 64
# act_3: sigmoid
# dropout_3: 0.5
# units_4: 32
# act_4: sigmoid
# dropout_4: 0.2
# learning_rate: 0.01
# Score: 0.9275093674659729

# %% [markdown]
# #### Build model with above parameter

# %%
create_DL_fixed_layer('DL_tune3', 5)
# Out:
#  units_0: 256 act_0: relu dropout_0: 0.1 units_1: 256 act_1: sigmoid dropout_1: 0.2 units_2: 196 act_2: relu dropout_2: 0.0 units_3: 196 act_3: sigmoid dropout_3: 0.1 units_4: 128 act_4: sigmoid dropout_4: 0.1 learning_rate: 0.001
# # MODEL DL_tune3
# backend.clear_session()
# DL_tune3 = Sequential()
#
# # Layer 1 (input layer)
# DL_tune3.add(Dense(256,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
# DL_tune3.add(Dropout(0.1))
# #Layer 2
# DL_tune3.add(Dense(256,activation='sigmoid',kernel_initializer='he_uniform'))
# DL_tune3.add(Dropout(0.2))
# #Layer 3
# DL_tune3.add(Dense(196,activation='relu',kernel_initializer='he_uniform'))
# DL_tune3.add(Dropout(0.0))
# #Layer 4
# DL_tune3.add(Dense(196,activation='sigmoid',kernel_initializer='he_uniform'))
# DL_tune3.add(Dropout(0.1))
# #Layer 5
# DL_tune3.add(Dense(128,activation='sigmoid',kernel_initializer='he_uniform'))
# DL_tune3.add(Dropout(0.1))
# #Output layer
# DL_tune3.add(Dense(1, activation = 'sigmoid'))
# optimizer = tf.keras.optimizers.Adam(0.001)
# DL_tune3.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
# history = DL_tune3.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
# accuracy_vs_epochs(history,20)
# dl_performance('DL_tune3', DL_tune3)

# %%
# MODEL DL_tune3
backend.clear_session()
DL_tune3 = Sequential()

# Layer 1 (input layer)
DL_tune3.add(Dense(256,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
DL_tune3.add(Dropout(0.1))
#Layer 2
DL_tune3.add(Dense(256,activation='sigmoid',kernel_initializer='he_uniform'))
DL_tune3.add(Dropout(0.2))
#Layer 3
DL_tune3.add(Dense(196,activation='relu',kernel_initializer='he_uniform'))
DL_tune3.add(Dropout(0.0))
#Layer 4
DL_tune3.add(Dense(196,activation='sigmoid',kernel_initializer='he_uniform'))
DL_tune3.add(Dropout(0.1))
#Layer 5
DL_tune3.add(Dense(128,activation='sigmoid',kernel_initializer='he_uniform'))
DL_tune3.add(Dropout(0.1))
#Output layer
DL_tune3.add(Dense(1, activation = 'sigmoid'))
optimizer = tf.keras.optimizers.Adam(0.001)
DL_tune3.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history = DL_tune3.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
accuracy_vs_epochs(history,20)
dl_performance('DL_tune3', DL_tune3)
# Out:
# Epoch 1/50
# 1062/1062 [==============================] - 4s 3ms/step - loss: 0.2607 - accuracy: 0.8895 - val_loss: 0.1957 - val_accuracy: 0.9135
# Epoch 2/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1851 - accuracy: 0.9214 - val_loss: 0.1632 - val_accuracy: 0.9278
# Epoch 3/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1627 - accuracy: 0.9300 - val_loss: 0.1412 - val_accuracy: 0.9370
# Epoch 4/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1456 - accuracy: 0.9365 - val_loss: 0.1431 - val_accuracy: 0.9389
# Epoch 5/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1369 - accuracy: 0.9402 - val_loss: 0.1326 - val_accuracy: 0.9438
# Epoch 6/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1301 - accuracy: 0.9433 - val_loss: 0.1284 - val_accuracy: 0.9413
# Epoch 7/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1238 - accuracy: 0.9459 - val_loss: 0.1238 - val_accuracy: 0.9458
# Epoch 8/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1194 - accuracy: 0.9480 - val_loss: 0.1215 - val_accuracy: 0.9458
# Epoch 9/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1145 - accuracy: 0.9501 - val_loss: 0.1208 - val_accuracy: 0.9487
# Epoch 10/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1116 - accuracy: 0.9511 - val_loss: 0.1227 - val_accuracy: 0.9461
# Epoch 11/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1096 - accuracy: 0.9532 - val_loss: 0.1218 - val_accuracy: 0.9469
# Epoch 12/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1069 - accuracy: 0.9536 - val_loss: 0.1271 - val_accuracy: 0.9485
# Epoch 13/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1038 - accuracy: 0.9546 - val_loss: 0.1163 - val_accuracy: 0.9501
# Epoch 14/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1043 - accuracy: 0.9545 - val_loss: 0.1183 - val_accuracy: 0.9506
# Epoch 15/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1003 - accuracy: 0.9563 - val_loss: 0.1186 - val_accuracy: 0.9502
# Epoch 16/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.0995 - accuracy: 0.9565 - val_loss: 0.1177 - val_accuracy: 0.9486
# Epoch 17/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.
50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.0651 - accuracy: 0.9710 - val_loss: 0.1440 - val_accuracy: 0.9510
# Epoch 49/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.0649 - accuracy: 0.9714 - val_loss: 0.1500 - val_accuracy: 0.9497
# Epoch 50/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.0633 - accuracy: 0.9718 - val_loss: 0.1512 - val_accuracy: 0.9501
# 2360/2360 [==============================] - 2s 904us/step
# 590/590 [==============================] - 1s 897us/step
# Model: DL_tune3
# Accuracy train: 0.97873
# Accuracy test: 0.95364
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      8576
#            1       0.96      0.96      0.96     10300
#
#     accuracy                           0.95     18876
#    macro avg       0.95      0.95      0.95     18876
# weighted avg       0.95      0.95      0.95     18876

# %% [markdown]
# ### 6/ 6 layers

# %%
backend.clear_session()

# %%
def build_model(h):
    model = keras.Sequential()
    # Number of layer: min - max
    no_of_layers = 6 # h.Int('num_layers', 2, 8)
    neurons_per_layer = [32,32,64,128,196,256,256,256,320,320,320,320]

    for i in range(no_of_layers):
        model.add(layers.Dense(
            units=h.Choice('units_' + str(i), neurons_per_layer[(no_of_layers-i):(no_of_layers-i+3)]),
            # Activation function for each layer
            activation= h.Choice('act_' + str(i), ['relu','sigmoid'])))
        # Tune with dropout or not
        model.add(Dropout(h.Choice('dropout_'+ str(i), [0.0, 0.1,0.2,0.5])))
    # output layer
    model.add(layers.Dense(1, activation='sigmoid'))
    # compiler
    model.compile(
        # Adjust learning rate
        optimizer=keras.optimizers.Adam(h.Choice('learning_rate', [1e-2, 1e-3])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,  #defaul 5-7
    executions_per_trial=3, #defaul 3-5
    project_name='Job',
    overwrite=True)
#tuner.search_space_summary()
start = time.time()
tuner.search(X_train, y_train, epochs=8, # default about 5-10
             validation_data = (X_test,y_test))
print('Tuning completed in: ', round(time.time()-start,2),'s')
tuner.results_summary()
# Out:
# Trial 5 Complete [00h 03m 09s]
# val_accuracy: 0.9309528867403666
#
# Best val_accuracy So Far: 0.9515257477760315
# Total elapsed time: 00h 15m 31s
# INFO:tensorflow:Oracle triggered exit
# Tuning completed in:  930.6 s
# Results summary
# Results in .\Job
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000018DDB9839A0>
# Trial summary
# Hyperparameters:
# units_0: 320
# act_0: relu
# dropout_0: 0.2
# units_1: 256
# act_1: relu
# dropout_1: 0.5
# units_2: 196
# act_2: sigmoid
# dropout_2: 0.5
# units_3: 196
# act_3: relu
# dropout_3: 0.2
# units_4: 128
# act_4: sigmoid
# dropout_4: 0.1
# units_5: 64
# act_5: relu
# dropout_5: 0.5
# learning_rate: 0.001
# Score: 0.9515257477760315
# Trial summary
# Hyperparameters:
# units_0: 320
# act_0: relu
# dropout_0: 0.1
# units_1: 256
# act_1: relu
# dropout_1: 0.5
# units_2: 196
# act_2: sigmoid
# dropout_2: 0.1
# units_3: 196
# act_3: relu
# dropout_3: 0.0
# units_4: 64
# act_4: sigmoid
# dropout_4: 0.5
# units_5: 32
# act_5: sigmoid
# dropout_5: 0.5
# learning_rate: 0.001
# Score: 0.949989398320516
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: sigmoid
# dropout_0: 0.0
# units_1: 256
# act_1: relu
# dropout_1: 0.1
# units_2: 256
# act_2: sigmoid
# dropout_2: 0.0
# units_3: 128
# act_3: relu
# dropout_3: 0.2
# units_4: 196
# act_4: relu
# dropout_4: 0.5
# units_5: 64
# act_5: relu
# dropout_5: 0.1
# learning_rate: 0.001
# Score: 0.940559446811676
# Trial summary
# Hyperparameters:
# units_0: 320
# act_0: sigmoid
# dropout_0: 0.0
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.5
# units_2: 256
# act_2: relu
# dropout_2: 0.2
# units_3: 196
# act_3: sigmoid
# dropout_3: 0.5
# units_4: 128
# act_4: sigmoid
# dropout_4: 0.0
# units_5: 128
# act_5: sigmoid
# dropout_5: 0.1
# learning_rate: 0.001
# Score: 0.9367097616195679
# Trial summary
# Hyperparameters:
# units_0: 256
# act_0: sigmoid
# dropout_0: 0.5
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.1
# units_2: 196
# act_2: relu
# dropout_2: 0.0
# units_3: 256
# act_3: relu
# dropout_3: 0.2
# units_4: 196
# act_4: relu
# dropout_4: 0.1
# units_5: 64
# act_5: relu
# dropout_5: 0.5
# learning_rate: 0.001
# Score: 0.9309528867403666

# %% [markdown]
# #### Build model with above parameter

# %%
create_DL_fixed_layer('DL_tune4', 6)
# Out:
#  units_0: 320 act_0: relu dropout_0: 0.2 units_1: 256 act_1: relu dropout_1: 0.5 units_2: 196 act_2: sigmoid dropout_2: 0.5 units_3: 196 act_3: relu dropout_3: 0.2 units_4: 128 act_4: sigmoid dropout_4: 0.1 units_5: 64 act_5: relu dropout_5: 0.5 learning_rate: 0.001
# # MODEL DL_tune4
# backend.clear_session()
# DL_tune4 = Sequential()
#
# # Layer 1 (input layer)
# DL_tune4.add(Dense(320,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
# DL_tune4.add(Dropout(0.2))
# #Layer 2
# DL_tune4.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
# DL_tune4.add(Dropout(0.5))
# #Layer 3
# DL_tune4.add(Dense(196,activation='sigmoid',kernel_initializer='he_uniform'))
# DL_tune4.add(Dropout(0.5))
# #Layer 4
# DL_tune4.add(Dense(196,activation='relu',kernel_initializer='he_uniform'))
# DL_tune4.add(Dropout(0.2))
# #Layer 5
# DL_tune4.add(Dense(128,activation='sigmoid',kernel_initializer='he_uniform'))
# DL_tune4.add(Dropout(0.1))
# #Layer 6
# DL_tune4.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
# DL_tune4.add(Dropout(0.5))
# #Output layer
# DL_tune4.add(Dense(1, activation = 'sigmoid'))
# optimizer = tf.keras.optimizers.Adam(0.001)
# DL_tune4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
# history = DL_tune4.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
# accuracy_vs_epochs(history,20)
# dl_performance('DL_tune4', DL_tune4)

# %%
# MODEL DL_tune4
backend.clear_session()
DL_tune4 = Sequential()

# Layer 1 (input layer)
DL_tune4.add(Dense(320,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
DL_tune4.add(Dropout(0.2))
#Layer 2
DL_tune4.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
DL_tune4.add(Dropout(0.5))
#Layer 3
DL_tune4.add(Dense(196,activation='sigmoid',kernel_initializer='he_uniform'))
DL_tune4.add(Dropout(0.5))
#Layer 4
DL_tune4.add(Dense(196,activation='relu',kernel_initializer='he_uniform'))
DL_tune4.add(Dropout(0.2))
#Layer 5
DL_tune4.add(Dense(128,activation='sigmoid',kernel_initializer='he_uniform'))
DL_tune4.add(Dropout(0.1))
#Layer 6
DL_tune4.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
DL_tune4.add(Dropout(0.5))
#Output layer
DL_tune4.add(Dense(1, activation = 'sigmoid'))
optimizer = tf.keras.optimizers.Adam(0.001)
DL_tune4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history = DL_tune4.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
accuracy_vs_epochs(history,20)
dl_performance('DL_tune4', DL_tune4)
# Out:
# Epoch 1/50
# 1062/1062 [==============================] - 5s 4ms/step - loss: 0.3138 - accuracy: 0.8709 - val_loss: 0.2139 - val_accuracy: 0.9107
# Epoch 2/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.2345 - accuracy: 0.9072 - val_loss: 0.1881 - val_accuracy: 0.9184
# Epoch 3/50
# 1062/1062 [==============================] - 4s 3ms/step - loss: 0
50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1114 - accuracy: 0.9522 - val_loss: 0.1227 - val_accuracy: 0.9505
# Epoch 35/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1116 - accuracy: 0.9526 - val_loss: 0.1261 - val_accuracy: 0.9498
# Epoch 36/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1110 - accuracy: 0.9539 - val_loss: 0.1195 - val_accuracy: 0.9521
# Epoch 37/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1102 - accuracy: 0.9538 - val_loss: 0.1183 - val_accuracy: 0.9517
# Epoch 38/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1104 - accuracy: 0.9537 - val_loss: 0.1166 - val_accuracy: 0.9514
# Epoch 39/50
# 1062/1062 [==============================] - 5s 4ms/step - loss: 0.1087 - accuracy: 0.9548 - val_loss: 0.1198 - val_accuracy: 0.9498
# Epoch 40/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1101 - accuracy: 0.9534 - val_loss: 0.1175 - val_accuracy: 0.9514
# Epoch 41/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1076 - accuracy: 0.9551 - val_loss: 0.1178 - val_accuracy: 0.9515
# Epoch 42/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1080 - accuracy: 0.9543 - val_loss: 0.1197 - val_accuracy: 0.9539
# Epoch 43/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1070 - accuracy: 0.9544 - val_loss: 0.1238 - val_accuracy: 0.9515
# Epoch 44/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1065 - accuracy: 0.9546 - val_loss: 0.1213 - val_accuracy: 0.9529
# Epoch 45/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1072 - accuracy: 0.9556 - val_loss: 0.1187 - val_accuracy: 0.9517
# Epoch 46/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1070 - accuracy: 0.9540 - val_loss: 0.1185 - val_accuracy: 0.9538
# Epoch 47/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1070 - accuracy: 0.9545 - val_loss: 0.1214 - val_accuracy: 0.9536
# Epoch 48/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1058 - accuracy: 0.9556 - val_loss: 0.1198 - val_accuracy: 0.9535
# Epoch 49/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1057 - accuracy: 0.9566 - val_loss: 0.1245 - val_accuracy: 0.9525
# Epoch 50/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.1063 - accuracy: 0.9559 - val_loss: 0.1255 - val_accuracy: 0.9551
# 2360/2360 [==============================] - 2s 983us/step
# 590/590 [==============================] - 1s 969us/step
# Model: DL_tune4
# Accuracy train: 0.96515
# Accuracy test: 0.95433
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      8576
#            1       0.97      0.95      0.96     10300
#
#     accuracy                           0.95     18876
#    macro avg       0.95      0.95      0.95     18876
# weighted avg       0.95      0.95      0.95     18876

# %% [markdown]
# ### 7/ 7 layers

# %%
backend.clear_session()

# %%
def build_model(h):
    model = keras.Sequential()
    # Number of layer: min - max
    no_of_layers = 7 # h.Int('num_layers', 2, 8)
    neurons_per_layer = [32,32,64,128,196,256,256,256,320,320,320,320]

    for i in range(no_of_layers):
        model.add(layers.Dense(
            units=h.Choice('units_' + str(i), neurons_per_layer[(no_of_layers-i):(no_of_layers-i+3)]),
            # Activation function for each layer
            activation= h.Choice('act_' + str(i), ['relu','sigmoid'])))
        # Tune with dropout or not
        model.add(Dropout(h.Choice('dropout_'+ str(i), [0.0, 0.1,0.2,0.5])))
    # output layer
    model.add(layers.Dense(1, activation='sigmoid'))
    # compiler
    model.compile(
        # Adjust learning rate
        optimizer=keras.optimizers.Adam(h.Choice('learning_rate', [1e-2, 1e-3])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,  #defaul 5-7
    executions_per_trial=3, #defaul 3-5
    project_name='Job',
    overwrite=True)
#tuner.search_space_summary()
start = time.time()
tuner.search(X_train, y_train, epochs=8, # default about 5-10
             validation_data = (X_test,y_test))
print('Tuning completed in: ', round(time.time()-start,2),'s')
tuner.results_summary()
# Out:
# Trial 5 Complete [00h 03m 34s]
# val_accuracy: 0.7672529419263204
#
# Best val_accuracy So Far: 0.9391290545463562
# Total elapsed time: 00h 17m 21s
# INFO:tensorflow:Oracle triggered exit
# Tuning completed in:  1041.38 s
# Results summary
# Results in .\Job
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000018DE7E319D0>
# Trial summary
# Hyperparameters:
# units_0: 320
# act_0: sigmoid
# dropout_0: 0.0
# units_1: 320
# act_1: sigmoid
# dropout_1: 0.1
# units_2: 256
# act_2: relu
# dropout_2: 0.5
# units_3: 256
# act_3: relu
# dropout_3: 0.0
# units_4: 196
# act_4: sigmoid
# dropout_4: 0.0
# units_5: 128
# act_5: relu
# dropout_5: 0.2
# units_6: 128
# act_6: sigmoid
# dropout_6: 0.1
# learning_rate: 0.001
# Score: 0.9391290545463562
# Trial summary
# Hyperparameters:
# units_0: 320
# act_0: sigmoid
# dropout_0: 0.1
# units_1: 320
# act_1: relu
# dropout_1: 0.1
# units_2: 256
# act_2: relu
# dropout_2: 0.2
# units_3: 196
# act_3: relu
# dropout_3: 0.2
# units_4: 196
# act_4: relu
# dropout_4: 0.0
# units_5: 64
# act_5: relu
# dropout_5: 0.1
# units_6: 128
# act_6: relu
# dropout_6: 0.2
# learning_rate: 0.01
# Score: 0.9093204736709595
# Trial summary
# Hyperparameters:
# units_0: 320
# act_0: relu
# dropout_0: 0.0
# units_1: 320
# act_1: relu
# dropout_1: 0.2
# units_2: 256
# act_2: relu
# dropout_2: 0.5
# units_3: 196
# act_3: sigmoid
# dropout_3: 0.0
# units_4: 256
# act_4: sigmoid
# dropout_4: 0.5
# units_5: 128
# act_5: relu
# dropout_5: 0.2
# units_6: 128
# act_6: relu
# dropout_6: 0.0
# learning_rate: 0.01
# Score: 0.8595217863718668
# Trial summary
# Hyperparameters:
# units_0: 320
# act_0: relu
# dropout_0: 0.2
# units_1: 256
# act_1: sigmoid
# dropout_1: 0.1
# units_2: 256
# act_2: relu
# dropout_2: 0.5
# units_3: 256
# act_3: sigmoid
# dropout_3: 0.1
# units_4: 256
# act_4: relu
# dropout_4: 0.1
# units_5: 128
# act_5: relu
# dropout_5: 0.1
# units_6: 64
# act_6: sigmoid
# dropout_6: 0.0
# learning_rate: 0.01
# Score: 0.7672529419263204
# Trial summary
# Hyperparameters:
# units_0: 320
# act_0: sigmoid
# dropout_0: 0.1
# units_1: 320
# act_1: relu
# dropout_1: 0.2
# units_2: 256
# act_2: sigmoid
# dropout_2: 0.5
# units_3: 196
# act_3: relu
# dropout_3: 0.5
# units_4: 256
# act_4: sigmoid
# dropout_4: 0.0
# units_5: 196
# act_5: relu
# dropout_5: 0.0
# units_6: 32
# act_6: relu
# dropout_6: 0.2
# learning_rate: 0.01
# Score: 0.5456664562225342

# %% [markdown]
# #### Build model with above parameter

# %%
create_DL_fixed_layer('DL_tune5', 7)
# Out:
#  units_0: 320 act_0: sigmoid dropout_0: 0.0 units_1: 320 act_1: sigmoid dropout_1: 0.1 units_2: 256 act_2: relu dropout_2: 0.5 units_3: 256 act_3: relu dropout_3: 0.0 units_4: 196 act_4: sigmoid dropout_4: 0.0 units_5: 128 act_5: relu dropout_5: 0.2 units_6: 128 act_6: sigmoid dropout_6: 0.1
# # MODEL DL_tune5
# backend.clear_session()
# DL_tune5 = Sequential()
#
# # Layer 1 (input layer)
# DL_tune5.add(Dense(320,activation='sigmoid',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
# DL_tune5.add(Dropout(0.0))
# #Layer 2
# DL_tune5.add(Dense(320,activation='sigmoid',kernel_initializer='he_uniform'))
# DL_tune5.add(Dropout(0.1))
# #Layer 3
# DL_tune5.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
# DL_tune5.add(Dropout(0.5))
# #Layer 4
# DL_tune5.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
# DL_tune5.add(Dropout(0.0))
# #Layer 5
# DL_tune5.add(Dense(196,activation='sigmoid',kernel_initializer='he_uniform'))
# DL_tune5.add(Dropout(0.0))
# #Layer 6
# DL_tune5.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
# DL_tune5.add(Dropout(0.2))
# #Layer 7
# DL_tune5.add(Dense(128,activation='sigmoid',kernel_initializer='he_uniform'))
# DL_tune5.add(Dropout(0.1))
# #Output layer
# DL_tune5.add(Dense(1, activation = 'sigmoid'))
# optimizer = tf.keras.optimizers.Adam(0.001)
# DL_tune5.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
# history = DL_tune5.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
# accuracy_vs_epochs(history,20)
# dl_performance('DL_tune5', DL_tune5)

# %%
# MODEL DL_tune5
backend.clear_session()
DL_tune5 = Sequential()

# Layer 1 (input layer)
DL_tune5.add(Dense(320,activation='sigmoid',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
DL_tune5.add(Dropout(0.0))
#Layer 2
DL_tune5.add(Dense(320,activation='sigmoid',kernel_initializer='he_uniform'))
DL_tune5.add(Dropout(0.1))
#Layer 3
DL_tune5.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
DL_tune5.add(Dropout(0.5))
#Layer 4
DL_tune5.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
DL_tune5.add(Dropout(0.0))
#Layer 5
DL_tune5.add(Dense(196,activation='sigmoid',kernel_initializer='he_uniform'))
DL_tune5.add(Dropout(0.0))
#Layer 6
DL_tune5.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
DL_tune5.add(Dropout(0.2))
#Layer 7
DL_tune5.add(Dense(128,activation='sigmoid',kernel_initializer='he_uniform'))
DL_tune5.add(Dropout(0.1))
#Output layer
DL_tune5.add(Dense(1, activation = 'sigmoid'))
optimizer = tf.keras.optimizers.Adam(0.001)
DL_tune5.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history = DL_tune5.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.1)
accuracy_vs_epochs(history,20)
dl_performance('DL_tune5', DL_tune5)
# Out:
# Epoch 1/50
# 1062/1062 [==============================] - 4s 3ms/step - loss: 0.3410 - accuracy: 0.8495 - val_loss: 0.2288 - val_accuracy: 0.8984
# Epoch 2/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.2092 - accuracy: 0.9097 - val_loss: 0.1844 - val_accuracy: 0.9178
# Epoch 3/50
# 1062/1062 [==============================] - 4s 3ms/step - loss: 0.1844 - accuracy: 0.9213 - val_loss: 0.1753 - val_accuracy: 0.9204
# Epoch 4/50
# 1062/1062 [==============================] - 4s 3ms/step - loss: 0.1693 - accuracy: 0.9259 - val_loss: 0.1576 - val_accuracy: 0.9270
# Epoch 5/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1604 - accuracy: 0.9313 - val_loss: 0.1516 - val_accuracy: 0.9323
# Epoch 6/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1501 - accuracy: 0.9357 - val_loss: 0.1448 - val_accuracy: 0.9325
# Epoch 7/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1436 - accuracy: 0.9385 - val_loss: 0.1338 - val_accuracy: 0.9384
# Epoch 8/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1389 - accuracy: 0.9401 - val_loss: 0.1340 - val_accuracy: 0.9407
# Epoch 9/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1350 - accuracy: 0.9420 - val_loss: 0.1337 - val_accuracy: 0.9389
# Epoch 10/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1330 - accuracy: 0.9431 - val_loss: 0.1298 - val_accuracy: 0.9416
# Epoch 11/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1282 - accuracy: 0.9445 - val_loss: 0.1294 - val_accuracy: 0.9431
# Epoch 12/50
# 1062/1062 [==============================] - 3s 3ms/step - loss: 0.1268 - accuracy: 0.9456 - val_loss: 0.1533 - val_accuracy: 0.9342
# Epoch 13/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.
50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.0905 - accuracy: 0.9611 - val_loss: 0.1210 - val_accuracy: 0.9499
# Epoch 44/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.0911 - accuracy: 0.9607 - val_loss: 0.1221 - val_accuracy: 0.9489
# Epoch 45/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.0900 - accuracy: 0.9607 - val_loss: 0.1249 - val_accuracy: 0.9506
# Epoch 46/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.0876 - accuracy: 0.9622 - val_loss: 0.1256 - val_accuracy: 0.9506
# Epoch 47/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.0876 - accuracy: 0.9621 - val_loss: 0.1239 - val_accuracy: 0.9494
# Epoch 48/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.0885 - accuracy: 0.9620 - val_loss: 0.1254 - val_accuracy: 0.9518
# Epoch 49/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.0863 - accuracy: 0.9625 - val_loss: 0.1316 - val_accuracy: 0.9510
# Epoch 50/50
# 1062/1062 [==============================] - 4s 4ms/step - loss: 0.0870 - accuracy: 0.9622 - val_loss: 0.1363 - val_accuracy: 0.9505
# 2360/2360 [==============================] - 3s 1ms/step
# 590/590 [==============================] - 1s 1ms/step
# Model: DL_tune5
# Accuracy train: 0.96425
# Accuracy test: 0.9537
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      8576
#            1       0.97      0.95      0.96     10300
#
#     accuracy                           0.95     18876
#    macro avg       0.95      0.95      0.95     18876
# weighted avg       0.95      0.95      0.95     18876

# %% [markdown]
# ### Result

# %%
df_accuracy
# Out:
#   Model name                                        Model arch.  \
# 0   DL_tune1  <keras.engine.sequential.Sequential object at ...
# 1   DL_tune2  <keras.engine.sequential.Sequential object at ...
# 2   DL_tune3  <keras.engine.sequential.Sequential object at ...
# 3   DL_tune4  <keras.engine.sequential.Sequential object at ...
# 4   DL_tune5  <keras.engine.sequential.Sequential object at ...
#
#    Train Accuracy  Test_Accuracy  Time
# 0         0.96556        0.95264     0
# 1         0.96670        0.95327     0
# 2         0.97873        0.95364     0
# 3         0.96515        0.95433     0
# 4         0.96425        0.95370     0

# %% [markdown]
# ### Make prediction on the submission set

# %%
model_list = [
              (DL_tune1,'DL_tune1'),
              (DL_tune2,'DL_tune2'),
              (DL_tune3,'DL_tune3'),
              (DL_tune4,'DL_tune4'),
              (DL_tune5,'DL_tune5'),
             ]

# %%
note_version = '6.1'

for model, model_name in model_list:
    export_submission(model_name, model, note_version)
print('All finish')
# Out:
# Exporting  DL_1 ...
# 1113/1113 [==============================] - 1s 746us/step
# Finish  submission_model_DL_1_fromfile_6.0.csv
# Exporting  DL_tune1 ...
# 1113/1113 [==============================] - 1s 870us/step
# Finish  submission_model_DL_tune1_fromfile_6.0.csv
# Exporting  DL_tune2 ...
# 1113/1113 [==============================] - 1s 888us/step
# Finish  submission_model_DL_tune2_fromfile_6.0.csv
# Exporting  DL_tune2a ...
# 1113/1113 [==============================] - 1s 1ms/step
# Finish  submission_model_DL_tune2a_fromfile_6.0.csv
# Exporting  DL_tune2b ...
# 1113/1113 [==============================] - 1s 1ms/step
# Finish  submission_model_DL_tune2b_fromfile_6.0.csv
# Exporting  DL_tune2c ...
# 1113/1113 [==============================] - 1s 1ms/step
# Finish  submission_model_DL_tune2c_fromfile_6.0.csv
# Exporting  DL_tune2d ...
# 1113/1113 [==============================] - 1s 851us/step
# Finish  submission_model_DL_tune2d_fromfile_6.0.csv
# All finish
